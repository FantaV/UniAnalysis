# %% [markdown]
# # Notebook Instructions
#
# 1. If you are new to Jupyter notebooks, please go through this introductory manual <a href='https://quantra.quantinsti.com/quantra-notebook' target="_blank">here</a>.
# 1. Any changes made in this notebook would be lost after you close the browser window. **You can download the notebook to save your work on your PC.**
# 1. Before running this notebook on your local PC:<br>
# i.  You need to set up a Python environment and the relevant packages on your local PC. To do so, go through the section on "**Run Codes Locally on Your Machine**" in the course.<br>
# ii. You need to **download the zip file available in the last unit** of this course. The zip file contains the data files and/or python modules that might be required to run this notebook.

# %% [markdown]
# # Fetching tweets
#
# In this notebook, you will learn to
# 1. [Get tweets with a specific word in it](#tweet)
# 2. [Increase the number of tweets fetched per request](#increase)
# 3. [Get tweet text and full tweet text](#full)
# 4. [Remove retweets](#remove)
# 5. [Get other information in a tweet such as the retweet count, user screen name and created at](#info)
# 6. [Keep tweets which are written in English language only](#english)
# 7. [Remove generic tweets](#generic)
#
# Note: The output for the code will change during runtime.

# %% [markdown]
# ## Authenticate and create an API object - you already know this!

# %%
# Import libraries
import tweepy
import os
import sys
sys.path.append("..")

# Import the get_twitter_tokens from the FMDA_quantra module
# The code of this module can be found in the downloads (last section) of this course
# You need to edit the FMDA_quantra.py file and add your Twitter tokens manually before you continue
from data_modules.FMDA_quantra import get_twitter_tokens

# Method in sentiment_analysis_quantra module to get the dictionary of consumer key and consumer secret
twitter_tokens = get_twitter_tokens()

# Set the consumer key and secret from the twitter_tokens dictionary
consumer_key = twitter_tokens['consumer_key']
consumer_secret = twitter_tokens['consumer_secret']


auth = tweepy.AppAuthHandler(consumer_key, consumer_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %% [markdown]
# <a id='tweet'></a>
# ## Tweets with specific words in it
#
# The `search` method of the API object can be used to search for the presence of a specific word in the tweet. For example, to search for the word 'AMZN' with a dollar sign in the tweet pass the parameter as shown below to the search method.

# %%
tweets_search_result = api.search(q = '$AMZN')

# %% [markdown]
# The output of the `search` method is the `SearchResults` object. It contains the information of the tweets which match the search criteria. By default, a maximum of 15 recent tweets are returned that matches the search criteria. The output is stored in `tweets_search_result`.

# %%
type(tweets_search_result)
# Out:
# tweepy.models.SearchResults

# %%
tweets_search_result
# Out:
# [Status(_api=<tweepy.api.API object at 0x000001EDFD40BCD0>, _json={'created_at': 'Wed May 26 08:43:16 +0000 2021', 'id': 1397473397471330307, 'id_str': '1397473397471330307', 'text': 'Market Briefing For Wednesday, May 26 $DAL $AMZN $SPY $BTC.X https://t.co/kD2dp0guAj', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [{'text': 'DAL', 'indices': [38, 42]}, {'text': 'AMZN', 'indices': [43, 48]}, {'text': 'SPY', 'indices': [49, 53]}, {'text': 'BTC.X', 'indices': [54, 60]}], 'user_mentions': [], 'urls': [{'url': 'https://t.co/kD2dp0guAj', 'expanded_url': 'https://talkmarkets.com/content/us-markets/market-briefing-for-wednesday-may-26?post=313480', 'display_url': 'talkmarkets.com/content/us-mar…', 'indices': [61, 84]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://talkmarkets.com" rel="nofollow">TalkMarketsApp</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1001192245, 'id_str': '1001192245', 'name': 'TalkMarkets', 'screen_name': 'TalkMarkets', 'location': '', 'description': 'Financial content that’s customized, optimized, socialized. #talkmarkets', 'url': 'http://t.co/iL0trK2OzM', 'entities': {'url': {'urls': [{'url': 'http://t.co/iL0trK2OzM', 'expanded_url': 'http://www.TalkMarkets.com', 'display_url': 'TalkMarkets.com', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 4595, 'friends_count': 1137, 'listed_count': 594, 'created_at': 'Mon Dec 10 07:55:31 +0000 2012', 'favourites_count': 474, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 279778, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '022330', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/876851529990512641/zRRSWFBW_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/876851529990512641/zRRSWFBW_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1001192245/1570606424', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'A8C7F7', 'profile_sidebar_fill_color': 'C0DFEC', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 5, 26, 8, 43, 16), id=1397473397471330307, id_str='1397473397471330307', text='Market Briefing For Wednesday, May 26 $DAL $AMZN $SPY $BTC.X https://t.co/kD2dp0guAj', truncated=False, entities={'hashtags': [], 'symbols': [{'text': 'DAL', 'indices': [38, 42]}, {'text': 'AMZN', 'indices': [43, 48]}, {'text': 'SPY', 'indices': [49, 53]}, {'text': 'BTC.X', 'indices': [54, 60]}], 'user_mentions': [], 'urls': [{'url': 'https://t.co/kD2dp0guAj', 'expanded_url': 'https://talkmarkets.com/content/us-markets/market-briefing-for-wednesday-may-26?post=313480', 'display_url': 'talkmarkets.com/content/us-mar…', 'indices': [61, 84]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='TalkMarketsApp', source_url='https://talkmarkets.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x000 ...
#  Status(_api=<tweepy.api.API object at 0x000001EDFD40BCD0>, _json={'created_at': 'Wed May 26 08:41:52 +0000 2021', 'id': 1397473047242625030, 'id_str': '1397473047242625030', 'text': '$AMZN At Wednesday’s shareholder meeting — typically hosted in Seattle but held virtually this year — Amazon’s inve… https://t.co/5VbJ3fFcLB', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [{'text': 'AMZN', 'indices': [0, 5]}], 'user_mentions': [], 'urls': [{'url': 'https://t.co/5VbJ3fFcLB', 'expanded_url': 'https://twitter.com/i/web/status/1397473047242625030', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1340663024722399232, 'id_str': '1340663024722399232', 'name': 'Ekalavya 📈', 'screen_name': 'EkalavyaHere', 'location': 'Cosmopolitan', 'description': 'Guiding Traders & building a Powerful community', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 284, 'friends_count': 267, 'listed_count': 2, 'created_at': 'Sun Dec 20 14:19:31 +0000 2020', 'favourites_count': 955, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 40, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1349755089200664577/Rjpzy9GO_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1349755089200664577/Rjpzy9GO_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1340663024722399232/1610642135', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 5, 26, 8, 41, 52), id=1397473047242625030, id_str='1397473047242625030', text='$AMZN At Wednesday’s shareholder meeting — typically hosted in Seattle but held virtually this year — Amazon’s inve… https://t.co/5VbJ3fFcLB', truncated=True, entities={'hashtags': [], 'symbols': [{'text': 'AMZN', 'indices': [0, 5]}], 'user_mentions': [], 'urls': [{'url': 'https://t.co/5VbJ3fFcLB', 'expanded_url': 'https://twitter.com/i/web/status/1397473047242625030', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x000001EDFD40BCD0>, _json={'id': 1340663024722399232, 'id_str': '1340663024722399232', 'name': 'Ekalavya 📈', 'screen_name': 'EkalavyaHere', 'location': 'Cosmopolitan', 'description': 'Guiding Traders & building a Powerful community', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 284, 'friends_count': 267, 'listed_count': 2, 'created_at': 'Sun Dec 20 14:19:31 +0000 2020', 'favourites_count': 955, 'utc_offset': None ...
#  Status(_api=<tweepy.api.API object at 0x000001EDFD40BCD0>, _json={'created_at': 'Wed May 26 08:38:40 +0000 2021', 'id': 1397472241101770752, 'id_str': '1397472241101770752', 'text': 'Looking at tech long swings just *incase* the June candle is the breakout. Nice r/r here on the off chance. Main targets $aapl $amzn', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [{'text': 'aapl', 'indices': [121, 126]}, {'text': 'amzn', 'indices': [127, 132]}], 'user_mentions': [], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3480686255, 'id_str': '3480686255', 'name': 'Hewitt Trades', 'screen_name': 'Hewitttrades', 'location': '', 'description': "UK,26-Gotta sacrifice for what you want the most. Posting a lot of charts for accountability-Don't follow my posts or you will lose money! Price over indicators", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 445, 'friends_count': 1476, 'listed_count': 10, 'created_at': 'Sat Aug 29 13:29:48 +0000 2015', 'favourites_count': 15998, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 4991, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1313175981541199872/FCGu59_J_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1313175981541199872/FCGu59_J_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3480686255/1594407809', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 5, 26, 8, 38, 40), id=1397472241101770752, id_str='1397472241101770752', text='Looking at tech long swings just *incase* the June candle is the breakout. Nice r/r here on the off chance. Main targets $aapl $amzn', truncated=False, entities={'hashtags': [], 'symbols': [{'text': 'aapl', 'indices': [121, 126]}, {'text': 'amzn', 'indices': [127, 132]}], 'user_mentions': [], 'urls': []}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x000001EDFD40BCD0>, _json={'id': 3480686255, 'id_str': '3480686255', 'name': 'Hewitt Trades', 'screen_name': 'Hewitttrades', 'location': '', 'description': "UK,26-Gotta sacrifice for what you want the most. Posting a lot of charts for accountability-Don't follow my posts or you will lose money! Price over indicators", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 445, 'friends_count': 1476, 'listed_count': 10, 'created_at': 'Sat Aug 29 13:29:48 +0000 2015', 'favourites_count': 15998, 'utc_offset': None, 'time_zone':  ...
#  Status(_api=<tweepy.api.API object at 0x000001EDFD40BCD0>, _json={'created_at': 'Wed May 26 08:33:40 +0000 2021', 'id': 1397470981694840835, 'id_str': '1397470981694840835', 'text': 'RT @garyblack00: If you like $TSLA but not the P/E, consider $AMZN at end of 2017: You could could have bought AMZN for $1,000, at 250x-300…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [{'text': 'TSLA', 'indices': [29, 34]}, {'text': 'AMZN', 'indices': [61, 66]}], 'user_mentions': [{'screen_name': 'garyblack00', 'name': 'Gary Black', 'id': 1161703589942878208, 'id_str': '1161703589942878208', 'indices': [3, 15]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1385939866047893512, 'id_str': '1385939866047893512', 'name': 'www.savedbytesla.com', 'screen_name': 'TeslaSaved', 'location': '', 'description': 'Here to fight #Tesla #FUD. https://t.co/0Wk6FzsguX\nhttps://t.co/1ZZA53ztxb\nhttps://t.co/GZhNGX2eGT\nhttps://t.co/Xs0GNO0B7r', 'url': None, 'entities': {'description': {'urls': [{'url': 'https://t.co/0Wk6FzsguX', 'expanded_url': 'http://www.savedbytesla.com', 'display_url': 'savedbytesla.com', 'indices': [27, 50]}, {'url': 'https://t.co/1ZZA53ztxb', 'expanded_url': 'https://www.patreon.com/SavedByTesla', 'display_url': 'patreon.com/SavedByTesla', 'indices': [51, 74]}, {'url': 'https://t.co/GZhNGX2eGT', 'expanded_url': 'https://www.buymeacoffee.com/savedbytesla', 'display_url': 'buymeacoffee.com/savedbytesla', 'indices': [75, 98]}, {'url': 'https://t.co/Xs0GNO0B7r', 'expanded_url': 'https://ko-fi.com/savedbytesla', 'display_url': 'ko-fi.com/savedbytesla', 'indices': [99, 122]}]}}, 'protected': False, 'followers_count': 99, 'friends_count': 781, 'listed_count': 0, 'created_at': 'Sat Apr 24 12:53:24 +0000 2021', 'favourites_count': 1186, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 920, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1385940735485165568/ADMY2knq_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1385940735485165568/ADMY2knq_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1385939866047893512/1619269285', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue May 25 16:29:47 +0000 2021', 'id': 1397228411630858240, 'id_str': '1397228411630858240', 'text': 'If you like $TSLA but not the P/E, consider $AMZN at end of 2017: You could could have bought AMZN for $1,000, at 2… https://t.co/KiAgMiCyDX', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [{'text': 'TSLA', 'indices': [12, 17]}, {'text': 'AMZN', 'indices': [44, 49]}], 'user_mentions': [], 'urls': [{'url': 'https://t.co/KiAgMiCyDX', 'expanded_url': 'https://twitter.com/i/web/status/1397228411630858240', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id ...
#  Status(_api=<tweepy.api.API object at 0x000001EDFD40BCD0>, _json={'created_at': 'Wed May 26 08:24:31 +0000 2021', 'id': 1397468681240813568, 'id_str': '1397468681240813568', 'text': 'RT @cranage91608618: #copper\n$AAPL $AMD $AMZN $BA $BABA $FB $NFLX $NIO $SPY $SQ $TSLA $ZM $qqq $dia $T $csco \n@BloombergTV \nRiotinto \n#iron…', 'truncated': False, 'entities': {'hashtags': [{'text': 'copper', 'indices': [21, 28]}, {'text': 'iron', 'indices': [134, 139]}], 'symbols': [{'text': 'AAPL', 'indices': [29, 34]}, {'text': 'AMD', 'indices': [35, 39]}, {'text': 'AMZN', 'indices': [40, 45]}, {'text': 'BA', 'indices': [46, 49]}, {'text': 'BABA', 'indices': [50, 55]}, {'text': 'FB', 'indices': [56, 59]}, {'text': 'NFLX', 'indices': [60, 65]}, {'text': 'NIO', 'indices': [66, 70]}, {'text': 'SPY', 'indices': [71, 75]}, {'text': 'SQ', 'indices': [76, 79]}, {'text': 'TSLA', 'indices': [80, 85]}, {'text': 'ZM', 'indices': [86, 89]}, {'text': 'qqq', 'indices': [90, 94]}, {'text': 'dia', 'indices': [95, 99]}, {'text': 'T', 'indices': [100, 102]}, {'text': 'csco', 'indices': [103, 108]}], 'user_mentions': [{'screen_name': 'cranage91608618', 'name': 'cranage', 'id': 1116465122594230273, 'id_str': '1116465122594230273', 'indices': [3, 19]}, {'screen_name': 'BloombergTV', 'name': 'Bloomberg TV', 'id': 35002876, 'id_str': '35002876', 'indices': [110, 122]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://gambiste.com" rel="nofollow">Gambiste</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1136370591517290496, 'id_str': '1136370591517290496', 'name': 'Joe Gambiste', 'screen_name': 'Gambiste1', 'location': '', 'description': 'Check out the best tweets on Stocks. Beware, I am the greatest stocks retweeter. Find hot stocks with @GambisteFinance.', 'url': 'https://t.co/qo0E93oDSt', 'entities': {'url': {'urls': [{'url': 'https://t.co/qo0E93oDSt', 'expanded_url': 'http://Gambiste.com', 'display_url': 'Gambiste.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 11609, 'friends_count': 0, 'listed_count': 154, 'created_at': 'Wed Jun 05 20:33:56 +0000 2019', 'favourites_count': 7442, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1248006, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1283519597640122368/X8uTqLDm_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1283519597640122368/X8uTqLDm_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed May 26 07:17:27 +0000 2021', 'id': 1397451800052215811, 'id_str': '1397451800052215811', 'text': '#copper\n$AAPL $AMD $AMZN $BA $BABA $FB $NFLX $NIO $SPY $SQ $TSLA $ZM $qqq $dia $T $csco \n@BloombergTV \nRiotinto… https://t.co/gujox2HZ6g', 'truncated': True, 'entities': {'hashtags': [{'text': 'copper', 'indices': [0, 7]}], 'symbols': [{'text': 'AAPL', 'indices': [8, 13]}, {'text': 'AMD', 'indices': [14, 18]}, {'text': 'AMZN', 'indices': [19, 24]}, {'text': 'BA', 'indices': [25, 28]}, {'text': 'BABA', 'indices': [29, 34]}, {'text': 'FB', 'indices': [35, 38]}, {'text': 'NFLX', 'indices':  ...
#  Status(_api=<tweepy.api.API object at 0x000001EDFD40BCD0>, _json={'created_at': 'Wed May 26 08:19:07 +0000 2021', 'id': 1397467322235985922, 'id_str': '1397467322235985922', 'text': 'RT @PandaOptions: $TWTR Enters gap fill territory over 57.63 with the gap to 63.98. Near term targets over 57.63 are 59.41, 61.60 and 63\n\n$…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [{'text': 'TWTR', 'indices': [18, 23]}], 'user_mentions': [{'screen_name': 'PandaOptions', 'name': 'Panda Options 🐼', 'id': 427693716, 'id_str': '427693716', 'indices': [3, 16]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 30548033, 'id_str': '30548033', 'name': 'ICECOLD', 'screen_name': 'JKeyz06', 'location': 'Dallas TX', 'description': 'Profitable Novice Technical Trader*49ers/Lakers*#TeamMST. https://t.co/0N4idNsY3G', 'url': None, 'entities': {'description': {'urls': [{'url': 'https://t.co/0N4idNsY3G', 'expanded_url': 'https://housestockwatcher.com/summary_by_state', 'display_url': 'housestockwatcher.com/summary_by_sta…', 'indices': [58, 81]}]}}, 'protected': False, 'followers_count': 449, 'friends_count': 568, 'listed_count': 9, 'created_at': 'Sat Apr 11 23:12:15 +0000 2009', 'favourites_count': 5809, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 11247, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/945080372416655365/3IOWDagp_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/945080372416655365/3IOWDagp_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/30548033/1615834501', 'profile_link_color': '000000', 'profile_sidebar_border_color': 'DABF3E', 'profile_sidebar_fill_color': 'BCA738', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue May 25 23:30:43 +0000 2021', 'id': 1397334345023729668, 'id_str': '1397334345023729668', 'text': '$TWTR Enters gap fill territory over 57.63 with the gap to 63.98. Near term targets over 57.63 are 59.41, 61.60 and… https://t.co/OETlmHGVIn', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [{'text': 'TWTR', 'indices': [0, 5]}], 'user_mentions': [], 'urls': [{'url': 'https://t.co/OETlmHGVIn', 'expanded_url': 'https://twitter.com/i/web/status/1397334345023729668', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 427693716, 'id_str': '427693716', 'name': 'Panda Options 🐼', 'screen_name': 'PandaOptions', 'location': 'Jungle', 'description': 'Options Trader. Openly sharing my ideas in hopes to help others become independent traders. Twits are not investment advice.', 'url': 'https://t.co/fVKw7F8Rbf', 'entities': {'url': {'urls': [{'url': 'https://t.co/fVKw7F8Rbf', 'e ...
#  Status(_api=<tweepy.api.API object at 0x000001EDFD40BCD0>, _json={'created_at': 'Wed May 26 08:16:50 +0000 2021', 'id': 1397466747377111041, 'id_str': '1397466747377111041', 'text': 'RT @labourlabel: Amazon has fast become a massive fashion retailer, owning 100+ clothing brands &amp; making billions in the pandemic. Garment…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'labourlabel', 'name': 'Labour Behind The Label', 'id': 176775272, 'id_str': '176775272', 'indices': [3, 15]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 987553377633554433, 'id_str': '987553377633554433', 'name': 'Alonzo Suson', 'screen_name': 'SusonAlonzo', 'location': '', 'description': 'Organizer, traveller, music, philosophy, beauty, and kindness....\nRe-tweets does not mean endorsement....', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 214, 'friends_count': 313, 'listed_count': 1, 'created_at': 'Sat Apr 21 04:47:27 +0000 2018', 'favourites_count': 2272, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 2501, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/987652140603662337/S7ZqKmH5_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/987652140603662337/S7ZqKmH5_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/987553377633554433/1579484089', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed May 26 08:14:03 +0000 2021', 'id': 1397466044780924929, 'id_str': '1397466044780924929', 'text': 'Amazon has fast become a massive fashion retailer, owning 100+ clothing brands &amp; making billions in the pandemic. G… https://t.co/izFuGMrbZC', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/izFuGMrbZC', 'expanded_url': 'https://twitter.com/i/web/status/1397466044780924929', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [121, 144]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 176775272, 'id_str': '176775272', 'name': 'Labour Behind The Label', 'screen_name': 'labourlabel', 'location': 'UK', 'description': 'Labour Behind the Label support garment workers worldwide fighting for better rights and working conditions. We represent @cleanclothes in UK.', 'url': 'https://t.co/39yncd8H1N', 'entities': {'url': {'urls': [{'url': 'https://t.co/39yncd8H1N', 'expanded_url': 'https://labourbehindthelabel.org', 'display_url': 'labourbehindthelabel.org', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 13792, 'friends_count': 1383, 'listed_count': 313, 'created_at': 'Tue Aug 10 12:06:14 +0000 2010',  ...
#  Status(_api=<tweepy.api.API object at 0x000001EDFD40BCD0>, _json={'created_at': 'Wed May 26 08:16:32 +0000 2021', 'id': 1397466671959400450, 'id_str': '1397466671959400450', 'text': 'RT @labourlabel: Amazon has fast become a massive fashion retailer, owning 100+ clothing brands &amp; making billions in the pandemic. Garment…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'labourlabel', 'name': 'Labour Behind The Label', 'id': 176775272, 'id_str': '176775272', 'indices': [3, 15]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2281214377, 'id_str': '2281214377', 'name': 'Dulcie Fairhurst', 'screen_name': 'DulcieFairhurst', 'location': 'London ', 'description': 'She/them. Socialist. Trade unionist', 'url': 'https://t.co/tEQH5WyPWQ', 'entities': {'url': {'urls': [{'url': 'https://t.co/tEQH5WyPWQ', 'expanded_url': 'https://findyourunion.tuc.org.uk/', 'display_url': 'findyourunion.tuc.org.uk', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 1156, 'friends_count': 724, 'listed_count': 6, 'created_at': 'Tue Jan 07 21:50:24 +0000 2014', 'favourites_count': 2105, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 4702, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '1A1B1F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1296550757840420864/h5bebZdv_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1296550757840420864/h5bebZdv_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2281214377/1620760760', 'profile_link_color': '2FC2EF', 'profile_sidebar_border_color': '181A1E', 'profile_sidebar_fill_color': '252429', 'profile_text_color': '666666', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed May 26 08:14:03 +0000 2021', 'id': 1397466044780924929, 'id_str': '1397466044780924929', 'text': 'Amazon has fast become a massive fashion retailer, owning 100+ clothing brands &amp; making billions in the pandemic. G… https://t.co/izFuGMrbZC', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/izFuGMrbZC', 'expanded_url': 'https://twitter.com/i/web/status/1397466044780924929', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [121, 144]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 176775272, 'id_str': '176775272', 'name': 'Labour Behind The Label', 'screen_name': 'labourlabel', 'location': 'UK', 'description': 'Labour Behind the Label support garment workers worldwide fighting for better rights and working conditions. We represent @cleanclothes in UK.', 'url': 'https://t.co/39yncd8H1N', 'entities': {'url': {'urls': [{'url': 'https://t.co/39yncd8H1N', 'expanded_url': 'https://labourbehindthelabel.org', 'display_url': ...
#  Status(_api=<tweepy.api.API object at 0x000001EDFD40BCD0>, _json={'created_at': 'Wed May 26 08:15:02 +0000 2021', 'id': 1397466293243195395, 'id_str': '1397466293243195395', 'text': 'RT @joanponsbarcelo: Reflexión: Creo que la tecnología Blockchain es el futuro como en su día lo fue el internet. Sin embargo, esto no elim…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'joanponsbarcelo', 'name': 'Joan Pons Barceló', 'id': 3305610082, 'id_str': '3305610082', 'indices': [3, 19]}], 'urls': []}, 'metadata': {'iso_language_code': 'es', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3427985813, 'id_str': '3427985813', 'name': 'Ignagac', 'screen_name': 'ignagac', 'location': 'Barcelona, España', 'description': 'Ingeniero industrial, apasionado de la inversión', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 6, 'friends_count': 56, 'listed_count': 0, 'created_at': 'Mon Aug 17 12:28:52 +0000 2015', 'favourites_count': 9, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1394234696385581057/0NNsHduC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1394234696385581057/0NNsHduC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3427985813/1621244870', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed May 19 16:03:18 +0000 2021', 'id': 1395047421701496835, 'id_str': '1395047421701496835', 'text': 'Reflexión: Creo que la tecnología Blockchain es el futuro como en su día lo fue el internet. Sin embargo, esto no e… https://t.co/4FptIOmgDS', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/4FptIOmgDS', 'expanded_url': 'https://twitter.com/i/web/status/1395047421701496835', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'es', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3305610082, 'id_str': '3305610082', 'name': 'Joan Pons Barceló', 'screen_name': 'joanponsbarcelo', 'location': 'Alcúdia, Islas Baleares', 'description': 'Analista Digital & Data Science de profesión y apasionado de la inversión en valor', 'url': 'https://t.co/4e81b5zIlo', 'entities': {'url': {'urls': [{'url': 'https://t.co/4e81b5zIlo', 'expanded_url': 'http://enbuscadevalor.com/', 'display_url': 'enbuscadevalor.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 1051, 'friends_count': 233, 'listed_count': 31, 'created_at': 'Mon Jun 01 12:52:16 +0000 2015', 'favourites_count' ...
#  Status(_api=<tweepy.api.API object at 0x000001EDFD40BCD0>, _json={'created_at': 'Wed May 26 08:14:54 +0000 2021', 'id': 1397466260082937856, 'id_str': '1397466260082937856', 'text': 'RT @labourlabel: Amazon has fast become a massive fashion retailer, owning 100+ clothing brands &amp; making billions in the pandemic. Garment…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'labourlabel', 'name': 'Labour Behind The Label', 'id': 176775272, 'id_str': '176775272', 'indices': [3, 15]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 905967810, 'id_str': '905967810', 'name': 'Nick Rudikoff', 'screen_name': 'nickrudikoff', 'location': 'Switzerland ', 'description': 'campaigns director @uniglobalunion, #makeamazonpay\nviews mine', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 684, 'friends_count': 1147, 'listed_count': 9, 'created_at': 'Fri Oct 26 13:13:44 +0000 2012', 'favourites_count': 3016, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1598, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1372128132011020289/ILH0QTeh_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1372128132011020289/ILH0QTeh_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/905967810/1612857082', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed May 26 08:14:03 +0000 2021', 'id': 1397466044780924929, 'id_str': '1397466044780924929', 'text': 'Amazon has fast become a massive fashion retailer, owning 100+ clothing brands &amp; making billions in the pandemic. G… https://t.co/izFuGMrbZC', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/izFuGMrbZC', 'expanded_url': 'https://twitter.com/i/web/status/1397466044780924929', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [121, 144]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 176775272, 'id_str': '176775272', 'name': 'Labour Behind The Label', 'screen_name': 'labourlabel', 'location': 'UK', 'description': 'Labour Behind the Label support garment workers worldwide fighting for better rights and working conditions. We represent @cleanclothes in UK.', 'url': 'https://t.co/39yncd8H1N', 'entities': {'url': {'urls': [{'url': 'https://t.co/39yncd8H1N', 'expanded_url': 'https://labourbehindthelabel.org', 'display_url': 'labourbehindthelabel.org', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 13792, 'friends_count': 1383, 'listed_count': 313, 'created_ ...
#  Status(_api=<tweepy.api.API object at 0x000001EDFD40BCD0>, _json={'created_at': 'Wed May 26 08:14:44 +0000 2021', 'id': 1397466217510842368, 'id_str': '1397466217510842368', 'text': 'RT @labourlabel: Amazon has fast become a massive fashion retailer, owning 100+ clothing brands &amp; making billions in the pandemic. Garment…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'labourlabel', 'name': 'Labour Behind The Label', 'id': 176775272, 'id_str': '176775272', 'indices': [3, 15]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 4823668455, 'id_str': '4823668455', 'name': 'Hazards Campaign #Ventilation #ZeroCovid', 'screen_name': 'hazardscampaign', 'location': '', 'description': 'Hazards Campaign is network of health+safety groups, activists+ union safety reps.  Fighting for workers lives+ health. Follow/retweets may not = agreement', 'url': 'https://t.co/I0l8e5u3ei', 'entities': {'url': {'urls': [{'url': 'https://t.co/I0l8e5u3ei', 'expanded_url': 'http://www.hazardscampaign.org.uk', 'display_url': 'hazardscampaign.org.uk', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 3477, 'friends_count': 1350, 'listed_count': 103, 'created_at': 'Mon Jan 18 11:18:38 +0000 2016', 'favourites_count': 30590, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 45277, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1250876775959130112/j3x_okjG_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1250876775959130112/j3x_okjG_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4823668455/1605525765', 'profile_link_color': '981CEB', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed May 26 08:14:03 +0000 2021', 'id': 1397466044780924929, 'id_str': '1397466044780924929', 'text': 'Amazon has fast become a massive fashion retailer, owning 100+ clothing brands &amp; making billions in the pandemic. G… https://t.co/izFuGMrbZC', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/izFuGMrbZC', 'expanded_url': 'https://twitter.com/i/web/status/1397466044780924929', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [121, 144]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 176775272, 'id_str': '176775272', 'name': 'Labour Behind The Label', 'screen_name': 'labourlabel', 'location': 'UK', 'description': 'Labour Behind the Label support garment workers worldwide fighting for better rights and working conditions. We represent @cleanclothes in UK.', 'url': 'https://t.co/ ...

# %%
len(tweets_search_result)
# Out:
# 11

# %% [markdown]
# <a id='increase'></a>
# ## Increase the number of tweets fetched
#
# To increase the number of tweets fetched per request, you can use the `count` parameter of the `api.search` method. But you can get a maximum of 100 tweets per request. For example, in the below code, the count is set to 150 but only 100 tweets are returned.

# %%
tweets_search_result = api.search(q = '$AMZN', 
                                  count=150)
len(tweets_search_result)
# Out:
# 100

# %% [markdown]
# <a id='full'></a>
# ## Get the tweet text
#
# Each tweet contains information such as tweet text, user screen name, and created date. To fetch the text of the first tweet in the `tweets_search_result` you can use the below code.

# %%
# Store the first tweet information in the tweet variable
tweet = tweets_search_result[0]

# Access the text using the property text of the variable tweet
tweet_text = tweet.text

# Print the text of the tweet
print(tweet_text)
# Out:
# Market Briefing For Wednesday, May 26 $DAL $AMZN $SPY $BTC.X https://t.co/kD2dp0guAj

# %% [markdown]
# ## Get full tweet text
#
# The text of the tweet is truncated and only 140 characters are returned for this tweet. Therefore, if the actual tweet text is more than 140 characters then you will not be able to see the tweet. To fetch full tweet text, you will need to set the `tweet_mode` to `extended` as shown below.

# %%
tweets_search_result = api.search(q = '$AMZN', 
                                  count=100, 
                                  tweet_mode='extended')

tweet = tweets_search_result[0]
print(tweet.full_text)
# Out:
# Market Briefing For Wednesday, May 26 $DAL $AMZN $SPY $BTC.X https://t.co/kD2dp0guAj

# %% [markdown]
# <a id='remove'></a>
# ## Remove retweets
#
# However, this partially solves our problem as the retweets are still truncated to 140 characters. But we have the original tweet and the number of times it was retweeted. Therefore, we can remove all the retweets by adding `-filter:retweets` in the search string as shown below.

# %%
tweets_search_result = api.search(q = '$AMZN -filter:retweets', 
                                  count=100, 
                                  tweet_mode='extended')

tweet = tweets_search_result[0]
print(tweet.full_text)
# Out:
# Market Briefing For Wednesday, May 26 $DAL $AMZN $SPY $BTC.X https://t.co/kD2dp0guAj

# %% [markdown]
# <a id='info'></a>
# ## Print tweet information
#
# We have defined a function `print_tweet_info` to print other information such as id: a unique number to identify a tweet, the date and time (UTC) when the tweet was created, user screen name, tweet text, retweet count, favourite count and language of the tweet in a tabular format.

# %%
# tabulate helps to print the data in a tabular format
from tabulate import tabulate

# This function takes as input the tweet (tweepy.models.Status object) and prints information in that tweet.
def print_tweet_info(tweet):      
    tweet_info = [
                    ['Tweet ID: ', tweet.id_str],
                    ['Created At (UTC):', tweet.created_at],
                    ['User Screen Name: ', tweet.user.screen_name],
                    ['Tweet Text: ', tweet.full_text],
                    ['Retweet Count:', tweet.retweet_count],
                    ['Favourite Count:', tweet.favorite_count],
                    ['Language:', tweet.lang],                                   
                ]
    print(tabulate(tweet_info))

# %%
print_tweet_info(tweet)
# Out:
# -----------------  ------------------------------------------------------------------------------------
# Tweet ID:          1397473397471330307
# Created At (UTC):  2021-05-26 08:43:16
# User Screen Name:  TalkMarkets
# Tweet Text:        Market Briefing For Wednesday, May 26 $DAL $AMZN $SPY $BTC.X https://t.co/kD2dp0guAj
# Retweet Count:     0
# Favourite Count:   0
# Language:          en
# -----------------  ------------------------------------------------------------------------------------

# %% [markdown]
# <a id='english'></a>
# ## Keep only tweets in the English language
#
# To keep only the tweets in the English language, add the parameter `language='en'` to the search method.

# %%
tweets_search_result = api.search(q = '$AMZN -filter:retweets', 
                                  count=100, 
                                  tweet_mode='extended', 
                                  language='en')

# %% [markdown]
# <a id='generic'></a>
# ## Remove generic tweets
#
# There are many times when the tweet is generic and not specific to a particular stock and has all the stock tickers mentioned in it. We believe that such tweets help little in determining the sentiment around any stock and should be removed.
#
# You can count for the occurrence of the dollar sign in the tweet using the count method on the tweet text. If the occurrence of the dollar sign is more than 8 then it is a generic tweet and should be removed. Otherwise, the tweet can be kept.
#
# We have shown below two sample tweets, one with many tickers in it and the other with only one stock ticker in it.

# %%
tweet_text = "$BBDA draws huge volume and runs up 300%. $WDBG $LFAP $GNCP $SHLDQ $MXMG $MSPC $HPIL $CSOC $SHMP $FTEG $ACB $SGCP $VAPE $WWIO $DRUS $BLSP $WNBD $AAPL $TSLA $FB $DSCR $MSFT $BGFT $IFXY $ADTM $AMZN $SNAP $MLHC $MGTI $BRKK $NNRX $HRI $DMHI $VYST $PMPG https://t.co/n3jsNtItMy"
if tweet_text.count('$') >= 8:
    print("The tweet contains more than 8 tickers")
else:
    print("The tweet doesn't contains more than 8 tickers")
# Out:
# The tweet contains more than 8 tickers

# %%
tweet_text = "$AMZN draws huge volume and is in bull run."
if tweet_text.count('$') >= 8:
    print("The tweet contains more than 8 tickers")
else:
    print("The tweet doesn't contain more than 8 tickers")
# Out:
# The tweet doesn't contain more than 8 tickers

# %% [markdown]
# In the next notebook unit, you will learn how to fetch the tweets posted by a specific user and how to fetch tweets between specific dates.
