# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt 
# %matplotlib inline 
plt.style.use('classic')

# %%
# set EURUSD (remember the =X)
forex_data = yf.download('EURUSD=X', start='2022-01-01')

forex_data.index = pd.to_datetime(forex_data.index)

forex_data.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2024-09-06  1.111111  1.114964  1.106721  1.111111   1.111111       0
# 2024-09-09  1.108721  1.109139  1.103497  1.108721   1.108721       0
# 2024-09-10  1.103753  1.105033  1.101625  1.103753   1.103753       0
# 2024-09-11  1.102098  1.105498  1.100279  1.102098   1.102098       0
# 2024-09-12  1.101091  1.104753  1.100655  1.101091   1.101091       0

# %%
# plotting close price 
plt.figure(figsize=(10,7))
forex_data['Adj Close'].plot()

# set the title
plt.title('EUR/USD Data', fontsize=14)
plt.xlabel('Year-Month', fontsize=12)
plt.ylabel('Price', fontsize=12)

plt.show()
